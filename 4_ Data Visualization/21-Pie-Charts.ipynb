# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-05-05 11:09:34--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M   110MB/s    in 1.4s
#
# 2025-05-05 11:09:35 (110 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
print(df['DatabaseWantToWorkWith'].value_counts())
# Out:
# DatabaseWantToWorkWith
# PostgreSQL                                                         3738
# PostgreSQL;SQLite                                                  1533
# SQLite                                                             1476
# Microsoft SQL Server                                               1431
# MySQL                                                              1139
#                                                                    ...
# Elasticsearch;Microsoft SQL Server;MongoDB;Solr;SQLite                1
# MariaDB;MongoDB;MySQL;Neo4J;Redis;Snowflake                           1
# Clickhouse;Dynamodb;Elasticsearch;MySQL;PostgreSQL                    1
# H2;MySQL;Oracle;Snowflake                                             1
# Cassandra;Cockroachdb;Elasticsearch;H2;InfluxDB;Neo4J;Snowflake       1
# Name: count, Length: 8478, dtype: int64

# %%
##Write your code here
db_data = df['DatabaseWantToWorkWith'].dropna()

# Split multiple responses and flatten the list
all_dbs = db_data.str.split(';').explode()

# Count the frequency of each database
db_counts = all_dbs.value_counts()

# Select the top 5 databases
top_5_dbs = db_counts.head(5)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_dbs, labels=top_5_dbs.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.tight_layout()
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
devtype_data = df['DevType'].dropna()

# Split multiple roles and flatten the list
all_roles = devtype_data.str.split(';').explode()

# Count frequency of each developer role
role_counts = all_roles.value_counts()

# Get top 5 roles
top_5_roles = role_counts.head(5)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_roles, labels=top_5_roles.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel2.colors)
plt.title('Top 5 Developer Roles')
plt.axis('equal')  # Ensures pie is a circle
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
    columns = df.columns.tolist()
    print(columns)
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith
# ...

# %%
##Write your code here
opsys_data = df['OpSysProfessional use'].dropna()

# Count frequency of each operating system
opsys_counts = opsys_data.value_counts()

# Optional: limit to top N for clarity
top_opsys = opsys_counts.head(5)  # adjust number if needed

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_opsys, labels=top_opsys.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Top Operating Systems Used Professionally')
plt.axis('equal')  # Equal aspect ratio ensures pie chart is a circle
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
lang_data = df['LanguageHaveWorkedWith'].dropna()

# Split the semicolon-separated strings into individual languages
all_languages = lang_data.str.split(';').explode()

# Count occurrences of each language
language_counts = all_languages.value_counts()

# Select top 5 languages
top_languages = language_counts.head(5)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_languages, labels=top_languages.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
collab_data = df['NEWCollabToolsHaveWorkedWith'].dropna()

# Split the semicolon-separated values into individual tools
all_tools = collab_data.str.split(';').explode()

# Count the frequency of each tool
tool_counts = all_tools.value_counts()

# Select the top 5 tools
top_tools = tool_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_tools, labels=top_tools.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Top 5 Collaboration Tools Used in Professional Work')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
admired_languages = df['LanguageAdmired'].dropna()

# Split the semicolon-separated values into individual languages
all_admired_languages = admired_languages.str.split(';').explode()

# Count the frequency of each admired language
admired_language_counts = all_admired_languages.value_counts()

# Select the top 5 most admired languages
top_admired_languages = admired_language_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_admired_languages, labels=top_admired_languages.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Most Admired Programming Languages')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
ai_tools = df['AIToolCurrently Using'].dropna()

# Split the semicolon-separated tools into individual tools
all_ai_tools = ai_tools.str.split(';').explode()

# Count the frequency of each AI tool
ai_tool_counts = all_ai_tools.value_counts()

# Select the top 5 most used AI tools
top_ai_tools = ai_tool_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_ai_tools, labels=top_ai_tools.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 AI Tools Used by Developers')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
web_frameworks = df['WebframeWantToWorkWith'].dropna()

# Split the semicolon-separated frameworks into individual frameworks
all_web_frameworks = web_frameworks.str.split(';').explode()

# Count the frequency of each web framework
web_framework_counts = all_web_frameworks.value_counts()

# Select the top 5 most preferred web frameworks
top_web_frameworks = web_framework_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_web_frameworks, labels=top_web_frameworks.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Preferred Web Frameworks')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
embedded_technologies = df['EmbeddedWantToWorkWith'].dropna()

# Split the semicolon-separated technologies into individual ones
all_embedded_technologies = embedded_technologies.str.split(';').explode()

# Count the frequency of each embedded technology
embedded_technology_counts = all_embedded_technologies.value_counts()

# Select the top 5 most desired embedded technologies
top_embedded_technologies = embedded_technology_counts.head(5)

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_embedded_technologies, labels=top_embedded_technologies.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Most Desired Embedded Technologies')
plt.axis('equal')
plt.tight_layout()
plt.show()
